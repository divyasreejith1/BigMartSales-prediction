# %%
#Importing libraries into the python environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading of training and testing datasets

# %%
#train data

# %%
train_data=pd.read_csv(r'C:\Users\HATPL\Downloads\train_v9rqX0R.csv')

# %%
train_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#Understanding of training data

# %%
train_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train_data.shape
# Out:
# (8523, 12)

# %%
train_data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train_data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train_data.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
train_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#dropping of columns[ Item_Identifier,'Item_Fat_Content','Outlet_Identifier',Item_Type] since it is not important

# %%
train_data1=train_data.drop(['Item_Identifier','Item_Fat_Content','Outlet_Identifier','Item_Type'],axis=1)

# %%
train_data1
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
#Creating the small variables for outlet establishment year

# %%
train_data1['Outlet_Establishment_Year']=2022-train_data1['Outlet_Establishment_Year']

# %%
train_data1['Outlet_Establishment_Year']
# Out:
# 0       23
# 1       13
# 2       23
# 3       24
# 4       35
#         ..
# 8518    35
# 8519    20
# 8520    18
# 8521    13
# 8522    25
# Name: Outlet_Establishment_Year, Length: 8523, dtype: int64

# %%
train_data1
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                         23
# 1           5.920         0.019278   48.2692                         13
# 2          17.500         0.016760  141.6180                         23
# 3          19.200         0.000000  182.0950                         24
# 4           8.930         0.000000   53.8614                         35
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                         35
# 8519        8.380         0.046982  108.1570                         20
# 8520       10.600         0.035186   85.1224                         18
# 8521        7.210         0.145221  103.1332                         13
# 8522       14.800         0.044878   75.4670                         25
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
#checking for the missing values of train data

# %%
train_data1.isna().sum()
# Out:
# Item_Weight                  1463
# Item_Visibility                 0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
#distribution of item_weight

# %%
sns.distplot(train_data.Item_Weight,kde=True)
# Out:
# C:\Users\HATPL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.scatterplot(x=train_data['Item_MRP'],y=train_data['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
sns.boxplot(y=train_data['Item_MRP'],x=train_data['Item_Fat_Content'])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_MRP'>

# %%
sns.barplot(y=train_data['Item_Outlet_Sales'],x=train_data['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
correlation=train_data1.corr()
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
#Data preprocessing

# %%
#filling of the missing values of column 'Item_weight' with mean

# %%
train_data1['Item_Weight']=train_data1['Item_Weight'].fillna(train_data1['Item_Weight'].mean())

# %%
#filling the missing values of column'Outlet_Size' with mode since it is a categorical column

# %%
train_data1['Outlet_Size']=train_data1['Outlet_Size'].fillna(train_data1['Outlet_Size'].mode()[0])

# %%
train_data1.isna().sum()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#Log Transformation

# %%
train_data1['Item_Outlet_Sales']=np.log(1+train_data1['Item_Outlet_Sales'])

# %%
#Encoding of Categorical columns

# %%
#One hot Encoding

# %%
train_data1=pd.get_dummies(train_data1)

# %%
train_data1
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                         23
# 1           5.920         0.019278   48.2692                         13
# 2          17.500         0.016760  141.6180                         23
# 3          19.200         0.000000  182.0950                         24
# 4           8.930         0.000000   53.8614                         35
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                         35
# 8519        8.380         0.046982  108.1570                         20
# 8520       10.600         0.035186   85.1224                         18
# 8521        7.210         0.145221  103.1332                         13
# 8522       14.800         0.044878   75.4670                         25
#
#       Item_Outlet_Sales  Outlet_Size_High  Outlet_Size_Medium  \
# ...

# %%
#splitting the features and target

# %%
X=train_data1.drop('Item_Outlet_Sales',axis=1)
y=train_data1['Item_Outlet_Sales']

# %%
X
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                         23
# 1           5.920         0.019278   48.2692                         13
# 2          17.500         0.016760  141.6180                         23
# 3          19.200         0.000000  182.0950                         24
# 4           8.930         0.000000   53.8614                         35
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                         35
# 8519        8.380         0.046982  108.1570                         20
# 8520       10.600         0.035186   85.1224                         18
# 8521        7.210         0.145221  103.1332                         13
# 8522       14.800         0.044878   75.4670                         25
#
#       Outlet_Size_High  Outlet_Size_Medium  Outlet_Size_Small  \
# ...

# %%
X.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                  24.168133
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                  13.000000
# 25%       9.310000         0.026989    93.826500                  18.000000
# 50%      12.857645         0.053931   143.012800                  23.000000
# 75%      16.000000         0.094585   185.643700                  35.000000
# max      21.350000         0.328391   266.888400                  37.000000
#
#        Outlet_Size_High  Outlet_Size_Medium  Outlet_Size_Small  \
# count       8523.000000         8523.000000        8523.000000
# mean           0.109351            0.610466           0.280183
# std            0.312098            0.487673           0.449115
# ...

# %%
#splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %%
#Building model

# %% [markdown]
# # Linear Regression model

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso

# %%
lr=LinearRegression()
model1=lr.fit(X_train,y_train)
pred1=model1.predict(X_test)

# %%
pred1
# Out:
# array([6.99185611, 6.70195025, 6.68896439, ..., 6.67980957, 6.5774549 ,
#        7.2198897 ])

# %%
pd.DataFrame(pred1)
# Out:
#              0
# 0     6.991856
# 1     6.701950
# 2     6.688964
# 3     8.304348
# 4     8.005849
# ...        ...
# 1700  7.388667
# 1701  7.415064
# 1702  6.679810
# 1703  6.577455
# 1704  7.219890
#
# [1705 rows x 1 columns]

# %%
#Mean Squared Error and R2 score

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print('Mean squared error is: ',mean_squared_error(y_test,pred1))
print('Rsquared value is: ',r2_score(y_test,pred1))
# Out:
# Mean squared error is:  0.2837261328979548
# Rsquared value is:  0.7301300929106579

# %% [markdown]
# # Lasso Regression Model

# %%
ls=Lasso(alpha=0.009)
model2=ls.fit(X_train,y_train)
pred2=model2.predict(X_test)

# %%
pred2
# Out:
# array([7.02845569, 6.68672461, 6.66194123, ..., 6.71963838, 6.67300581,
#        7.24097021])

# %%
#Mean Squared Error and R2 score

# %%
print('Mean squared error is: ',mean_squared_error(y_test,pred2))
print('Rsquared value is: ',r2_score(y_test,pred2))
# Out:
# Mean squared error is:  0.29044108590892687
# Rsquared value is:  0.7237430755193761

# %% [markdown]
# # Ridge Regression

# %%
rid_reg=Ridge(alpha=0.009)
model3=rid_reg.fit(X_train,y_train)
pred3=model3.predict(X_test)

# %%
#Mean Squared Error and R2 score

# %%
print('Mean squared error is: ',mean_squared_error(y_test,pred3))
print('Rsquared value is: ',r2_score(y_test,pred3))
# Out:
# Mean squared error is:  0.283727045420273
# Rsquared value is:  0.7301292249528468

# %% [markdown]
# Linear Regression: 58.09845417725021%
#
# Lasso Regression: 58.09803086969754%
#
# Ridge Regression: 58.09834671920335%

# %% [markdown]
# Lasso Regression has low accuracy compared to linear and ridge regression models.The r2 score value of linear regression is more compared to ridge.Linear Regression has better MSE value when compared to other models.So by considering all these the best model for this dataset is LINEAR REGRESSION

# %% [markdown]
# # test data

# %%
test_data=pd.read_csv(r'C:\Users\HATPL\Downloads\test_AbJTz2l.csv')

# %%
test_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
test_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test_data.nunique()
# Out:
# Item_Identifier              1543
# Item_Weight                   410
# Item_Fat_Content                5
# Item_Visibility              5277
# Item_Type                      16
# Item_MRP                     4402
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# dtype: int64

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
#Checking for the null values of test data

# %%
test_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#dropping of columns[ Item_Identifier,'Item_Fat_Content','Outlet_Identifier',Item_Type] since it is not important

# %%
test_data1=test_data.drop(['Item_Identifier','Item_Fat_Content','Outlet_Identifier','Item_Type'],axis=1)

# %%
#creating the small variables for 'Outlet_Establishment_Year'

# %%
test_data1['Outlet_Establishment_Year']=2022-test_data1['Outlet_Establishment_Year']

# %%
test_data1
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0          20.750         0.007565  107.8622                         23
# 1           8.300         0.038428   87.3198                         15
# 2          14.600         0.099575  241.7538                         24
# 3           7.315         0.015388  155.0340                         15
# 4             NaN         0.118599  234.2300                         37
# ...           ...              ...       ...                        ...
# 5676       10.500         0.013496  141.3154                         25
# 5677        7.600         0.142991  169.1448                         13
# 5678       10.000         0.073529  118.7440                         20
# 5679       15.300         0.000000  214.6218                         15
# 5680        9.500         0.104720   79.7960                         20
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# ...

# %%
#filling of the missing values of column 'Item_weight' with mean

# %%
test_data1['Item_Weight']=test_data1['Item_Weight'].fillna(test_data1['Item_Weight'].mean())

# %%
#filling the missing values of column'Outlet_Size' with mode since it is a categorical column

# %%
test_data1['Outlet_Size']=test_data1['Outlet_Size'].fillna(test_data1['Outlet_Size'].mode()[0])

# %%
test_data1.isna().sum()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
#Encoding

# %%
#one hot encoding

# %%
test_data1=pd.get_dummies(test_data1)

# %%
test_data1.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0    20.750000         0.007565  107.8622                         23
# 1     8.300000         0.038428   87.3198                         15
# 2    14.600000         0.099575  241.7538                         24
# 3     7.315000         0.015388  155.0340                         15
# 4    12.695633         0.118599  234.2300                         37
#
#    Outlet_Size_High  Outlet_Size_Medium  Outlet_Size_Small  \
# 0                 0                   1                  0
# 1                 0                   1                  0
# 2                 0                   1                  0
# 3                 0                   1                  0
# 4                 0                   1                  0
#
#    Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# 0                            1                            0
# 1                            0                            1
# ...

# %%
#prediction of Item_outlet_sales

# %%
Item_Outlet_sales_pred=lr.predict(test_data1)

# %%
Item_Outlet_sales_pred
# Out:
# array([7.22681593, 7.10739258, 6.38503823, ..., 7.29126471, 8.15286935,
#        6.96479654])

# %%
#Applying inverse transformation

# %%
actual_item_outsale=np.exp(Item_Outlet_sales_pred+1)

# %%
actual_item_outsale
# Out:
# array([3739.90664951, 3318.91294023, 1611.68940457, ..., 3988.87579177,
#        9441.49249073, 2877.84359982])

# %%
#Adding the predicted values of item outlet sales to test data

# %%
test_data['Item_Outlet_Sales']=actual_item_outsale

# %%
test_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
test_data.to_csv('testPR.csv')

# %%
nw_test=pd.read_csv('testPR.csv')

# %%
nw_test.shape
# Out:
# (5681, 13)

# %%
import base64

# %%
from IPython.display import HTML


def create_download_link( test_data, title = "Download CSV file", filename = "data.csv"):  
    csv = test_data.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

create_download_link(test_data)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
